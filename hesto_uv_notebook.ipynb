# %% [markdown]
# # Hesto Notebook (uv environment)
# This notebook is configured to use the workspace Python environment managed by uv (.venv).

# %%
import sys
import pandas as pd
from pathlib import Path
from datetime import datetime
print(sys.executable)
# Out:
# c:\Users\shoffma5\Documents\GitHub_orig\hestodb\.venv\Scripts\python.exe

# %%
from hestodb.util import parse_file_path, find_latest_report_pptx
from hestodb.report import Report
from hestodb import _test_report_pptx
print(_test_report_pptx)
# Out:
# c:\Users\shoffma5\Documents\GitHub_orig\hestodb\hestodb\data\test\HESTO-202612_Report_24-HTIDS24_Smith-rev3.pptx

# %% [markdown]
# Checking the test file

# %%
test_report = Report(_test_report_pptx)
print(test_report)
# Out:
# Report HESTO-202612_Report_24-HTIDS24_Smith-rev3.pptx (33 slides)
# Project ID: 24-HTIDS24-0009, PI: Jane Smith
#
# Category    Prior    Current
# ----------  -------  -------
# overall     Y        Y
# cost        Y        Y
# schedule    G        G
# technical   G        G
# staffing    G        G
# facilities  G        G
#
# Accommodation:
# Category                          Sub-category  Value
# --------------------------------  ----------  --------------
# payload size                      length      10.0
#                                   width       10.0
#                                   height      10.0
# payload volume                                1.0
# power requirements                average     5.0
#                                   peak        10.0
# mass                                          5.4
# pointing requirements             arcsecs     60.0
#                                   arcminutes  1.0
# data rate                         average     15.0
#                                   peak        100.0
# power interface port                          db-9, 28 v, 1a
# communication interface protocol              uart
# data communication port                       db-9
# requires thermal isolation                    false
# special power considerations                  none
#
# Publications:
#       Type choose one of below                                                   Title Publication/Presentation Date Publisher/Conference Name                                           URL
# Conference presentation (oral) Development of the Next-Generation Solar X-ray detector                   23-Jan-2026              IEEE NSS/MIC https://ieeexplore.ieee.org/document/10657175

# %%
test_report.accomodation_table
# Out:
#                             category sub_category           value
# 0                       payload size       length            10.0
# 1                       payload size        width            10.0
# 2                       payload size       height            10.0
# 3                     payload volume                          1.0
# 4                 power requirements      average             5.0
# 5                 power requirements         peak            10.0
# 6                               mass                          5.4
# 7              pointing requirements      arcsecs            60.0
# 8              pointing requirements   arcminutes             1.0
# 9                          data rate      average            15.0
# 10                         data rate         peak           100.0
# 11              power interface port               db-9, 28 v, 1a
# 12  communication interface protocol                         uart
# 13           data communication port                         db-9
# 14        requires thermal isolation                        false
# 15      special power considerations                         none

# %%
test_report.publication_table
# Out:
#          Type choose one of below  \
# 0  Conference presentation (oral)
#
#                                                Title  \
# 0  Development of the Next-Generation Solar X-ray...
#
#   Publication/Presentation Date Publisher/Conference Name  \
# 0                   23-Jan-2026              IEEE NSS/MIC
#
#                                              URL
# 0  https://ieeexplore.ieee.org/document/10657175

# %%
test_report.patents_table
# Out:
#   Type (Issued, Filing)                                               Name  \
# 0                Issued  Art of transmitting electrical energy through ...
#
#   Patent or License Number        Date  \
# 0                US787412A  1900-05-16
#
#       Resource Link (e.g., Google Patents Link)
# 0  https://patents.google.com/patent/US787412A/

# %%
test_report.student_metrics_table
# Out:
#   Student Name (first last)    Major Affiliation (School, University, etc.)  \
# 0                  John Doe  Physics                  University of Alabama
#
#   Level (High School, Undergrad, Grad, PhD)
# 0                                 Undergrad

# %%
files = [
    find_latest_report_pptx(Path("C:\\Users\\shoffma5\\Box\\HESTO\\HTIDeS")),
    find_latest_report_pptx(Path("C:\\Users\\shoffma5\\Box\\HESTO\\HFOS")),
    find_latest_report_pptx(Path("C:\\Users\\shoffma5\\Box\\HESTO\\Special Projects"))
]
files = pd.concat(files, ignore_index=True)
print(f"Found {len(files)} report files:")
files.to_csv("report_files.csv", index=False)
files
# Out:
# Found 34 report files:
#                                             file_path       project_id  \
# 0   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0025
# 1   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0006
# 2   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0036
# 3   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0005
# 4   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0022
# 5   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0039
# 6   C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...  23-HTIDS23-0022
# 7   C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...  23-HTIDS23-0023
# 8   C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...  23-HITDS23-0001
# 9   C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...  23-HTIDS23-0016
# 10  C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...  23-HTIDS23-0011
# 11  C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...  23-HTIDS23-0017
# 12  C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...  23-HTIDS23-0004
# 13  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...  22-HTIDS22-0018
# 14  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...  22-HTIDS22-0014
# 15  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...  22-HTIDS22-0023
# 16  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...  22-HTIDS22-0008
# 17  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...  22-HTIDS22-0007
# 18  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...  22-HITDS22-0004
# 19  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...  22-HTIDS22-0013
# 20  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...  22-HTIDS22-0020
# 21  C:\Users\shoffma5\Box\HESTO\HTIDeS\21-HTIDS\21...  21-HTIDS21-0012
# 22  C:\Users\shoffma5\Box\HESTO\HTIDeS\21-HTIDS\21...  21-HTIDS21-0004
# 23  C:\Users\shoffma5\Box\HESTO\HTIDeS\20-HTIDS\20...  20-HTIDS20-0034
# 24  C:\Users\shoffma5\Box\HESTO\HTIDeS\20-HTIDS\20...  20-HTIDS20-0009
# 25  C:\Users\shoffma5\Box\HESTO\HTIDeS\20-HTIDS\20...  20-HTIDS20-0010
# 26  C:\Users\shoffma5\Box\HESTO\HTIDeS\20-HTIDS\20...  20-HTIDS20-0028
# 27  C:\Users\shoffma5\Box\HESTO\HTIDeS\19-HTIDS\19...  19-HTIDS19-0027
# 28  C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...   24-HFOS24-0013
# 29  C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...   24-HFOS24-0008
# 30  C:\Users\shoffma5\Box\HESTO\HFOS\23-HFOS\23-HF...   23-HFOS23-0003
# 31  C:\Users\shoffma5\Box\HESTO\HFOS\20-HFOS\20-HF...   20-HFOS20-0011
# 32  C:\Users\shoffma5\Box\HESTO\Special Projects\2...     22-PROJ-0001
# 33  C:\Users\shoffma5\Box\HESTO\Special Projects\1...  18-HTIDS18-0010
#
#    report_date  year principal_investigator            modified  \
# 0   2026-04-15  2024         Gregory Miller 2026-04-26 16:14:23
# 1   2026-04-15  2024            Shawn Liang 2026-04-29 11:58:54
# 2   2026-04-15  2024          Maria Usanova 2026-04-24 16:39:00
# 3   2026-05-15  2024       Georgia de Nolfo 2026-04-26 13:47:32
# 4   2026-05-15  2024       Lindsay Glesener 2026-06-10 10:51:52
# 5   2026-05-15  2024      Dhirendra Kataria 2026-06-09 15:58:16
# 6   2026-04-15  2023            Ed Thiemann 2026-04-23 11:13:11
# 7   2026-05-15  2023          Aroh Barjatya 2026-06-01 10:15:27
# 8   2026-05-15  2023           Mark Moldwin 2026-05-08 08:59:06
# 9   2026-04-15  2023      Juliana Vievering 2026-04-26 12:19:52
# 10  2026-04-15  2023                    Yoo 2026-04-23 15:01:00
# 11  2026-04-15  2023      Keiichi Ogasawara 2026-04-24 10:59:05
# 12  2026-05-15  2023        Jerry Goldstein 2026-04-26 15:05:51
# 13  2026-05-15  2022         Robert Clayton 2026-04-27 15:52:25
# 14  2026-04-15  2022        David Malaspina 2026-04-20 22:00:13
# 15  2026-04-15  2022             Justin Lee 2026-05-26 13:22:32
# 16  2026-04-15  2022         K. Kalogerakis 2026-04-26 20:35:28
# 17  2026-05-15  2022           Majd Mayyasi 2026-05-04 09:30:06
# 18  2026-04-15  2022        Jeffrey Newmark 2026-04-22 09:58:11
# 19  2026-04-15  2022     Mihailo Martinovic 2026-04-25 20:14:14
# 20  2026-04-15  2022             John McVey 2026-04-27 23:07:56
# 21  2026-04-15  2021         James Clemmons 2026-05-04 13:52:54
# 22  2026-05-15  2021          Xiaojia Zhang 2026-04-27 04:29:26
# 23  2026-04-15  2020              Hong Zhao 2026-04-26 09:46:23
# 24  2026-05-15  2020              Ian Cohen 2026-04-29 13:31:38
# 25  2026-04-15  2020           John Bonnell 2026-05-04 18:51:59
# 26  2026-05-15  2020  Seyedeh Sona Hosseini 2026-04-28 18:28:46
# 27  2026-04-15  2019                Sam Yee 2026-04-28 10:01:24
# 28  2026-04-15  2024          Greg Holsclaw 2026-04-29 18:57:30
# 29  2026-05-15  2024      Christopher Moore 2026-04-26 23:07:41
# 30  2026-04-15  2023              Hong Zhao 2026-04-26 09:33:58
# 31  2026-04-15  2020            Wendy Frank 2026-05-05 10:15:40
# 32  2026-05-15  2020            David Miles 2026-05-10 08:29:53
# 33  2026-05-15  2018            David Miles 2026-05-10 08:55:00
#
#                                                folder is_active
# 0   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 1   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 2   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 3   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 4   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 5   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 6   C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...       Yes
# 7   C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...       Yes
# 8   C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...       Yes
# 9   C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...       Yes
# 10  C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...       Yes
# 11  C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...       Yes
# 12  C:\Users\shoffma5\Box\HESTO\HTIDeS\23-HTIDS\23...       Yes
# 13  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...       Yes
# 14  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...       Yes
# 15  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...       Yes
# 16  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...       Yes
# 17  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...       Yes
# 18  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...       Yes
# 19  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...       Yes
# 20  C:\Users\shoffma5\Box\HESTO\HTIDeS\22-HTIDS\22...       Yes
# 21  C:\Users\shoffma5\Box\HESTO\HTIDeS\21-HTIDS\21...       Yes
# 22  C:\Users\shoffma5\Box\HESTO\HTIDeS\21-HTIDS\21...       Yes
# 23  C:\Users\shoffma5\Box\HESTO\HTIDeS\20-HTIDS\20...       Yes
# 24  C:\Users\shoffma5\Box\HESTO\HTIDeS\20-HTIDS\20...       Yes
# 25  C:\Users\shoffma5\Box\HESTO\HTIDeS\20-HTIDS\20...       Yes
# 26  C:\Users\shoffma5\Box\HESTO\HTIDeS\20-HTIDS\20...       Yes
# 27  C:\Users\shoffma5\Box\HESTO\HTIDeS\19-HTIDS\19...       Yes
# 28  C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...       Yes
# 29  C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...       Yes
# 30  C:\Users\shoffma5\Box\HESTO\HFOS\23-HFOS\23-HF...       Yes
# 31  C:\Users\shoffma5\Box\HESTO\HFOS\20-HFOS\20-HF...       Yes
# 32  C:\Users\shoffma5\Box\HESTO\Special Projects\2...       Yes
# 33  C:\Users\shoffma5\Box\HESTO\Special Projects\1...       Yes

# %%
files[files['year'] == 2024]
# Out:
#                                             file_path       project_id  \
# 0   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0025
# 1   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0006
# 2   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0036
# 3   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0005
# 4   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0022
# 5   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...  24-HTIDS24-0039
# 28  C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...   24-HFOS24-0013
# 29  C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...   24-HFOS24-0008
#
#    report_date  year principal_investigator            modified  \
# 0   2026-04-15  2024         Gregory Miller 2026-04-26 16:14:23
# 1   2026-04-15  2024            Shawn Liang 2026-04-29 11:58:54
# 2   2026-04-15  2024          Maria Usanova 2026-04-24 16:39:00
# 3   2026-05-15  2024       Georgia de Nolfo 2026-04-26 13:47:32
# 4   2026-05-15  2024       Lindsay Glesener 2026-06-10 10:51:52
# 5   2026-05-15  2024      Dhirendra Kataria 2026-06-09 15:58:16
# 28  2026-04-15  2024          Greg Holsclaw 2026-04-29 18:57:30
# 29  2026-05-15  2024      Christopher Moore 2026-04-26 23:07:41
#
#                                                folder is_active
# 0   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 1   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 2   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 3   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 4   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 5   C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...       Yes
# 28  C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...       Yes
# 29  C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...       Yes

# %%
test_file = files[files['year'] == 2024].iloc[0]['file_path']

# %%
this_report = Report(test_file)
# Out:
# HESTO-202604_Report_24-HTIDS24-0025_Miller-rev3_Apr26_2026.pptx: unrecognised publication type 'Peer-reviewed journal'. Expected one of: ['Peer-reviewed publication', 'Non-Peer-reviewed publication', 'Conference presentation (oral)', 'Conference presentation (poster)', 'Web article']
# HESTO-202604_Report_24-HTIDS24-0025_Miller-rev3_Apr26_2026.pptx: unrecognised publication type 'Non-peer-reviewed journal'. Expected one of: ['Peer-reviewed publication', 'Non-Peer-reviewed publication', 'Conference presentation (oral)', 'Conference presentation (poster)', 'Web article']

# %%
this_report
# Out:
# Report HESTO-202604_Report_24-HTIDS24-0025_Miller-rev3_Apr26_2026.pptx (40 slides)
# Project ID: 24-HTIDS24-0025 (80NSSC25K7661), PI: Gregory P. Miller
#
# Accommodation:
# Category                          Sub-category  Value
# --------------------------------  ----------  ----------------------
# payload size                      length      10.0
#                                   width       10.0
#                                   height      30.0
# payload volume                                3.0
# power requirements                average     5.0
#                                   peak        6.0
# mass                                          5.0
# pointing requirements             arcsecs     tbd
#                                   arcminutes  tbd
# data rate                         average     50.0
#                                   peak        tbd
# power interface port                          mdm-9, +14 v dc, tbd a
# communication interface protocol              rs422
# data communication port                       mdm-9
# requires thermal isolation                    false
# special power considerations                  none
#
# Publications:
#         Type choose one of below Title Publication/Presentation Date Publisher/Conference Name URL
#            Peer-reviewed journal
#        Non-peer-reviewed journal
#   Conference presentation (oral)
# Conference presentation (poster)
#                      Web article

# %%
this_report.accomodation_table
# Out:
#                             category sub_category                   value
# 0                       payload size       length                    10.0
# 1                       payload size        width                    10.0
# 2                       payload size       height                    30.0
# 3                     payload volume                                  3.0
# 4                 power requirements      average                     5.0
# 5                 power requirements         peak                     6.0
# 6                               mass                                  5.0
# 7              pointing requirements      arcsecs                     tbd
# 8              pointing requirements   arcminutes                     tbd
# 9                          data rate      average                    50.0
# 10                         data rate         peak                     tbd
# 11              power interface port               mdm-9, +14 v dc, tbd a
# 12  communication interface protocol                                rs422
# 13           data communication port                                mdm-9
# 14        requires thermal isolation                                false
# 15      special power considerations                                 none

# %%
this_report.publication_table
# Out:
#            Type choose one of below Title Publication/Presentation Date  \
# 0             Peer-reviewed journal
# 1         Non-peer-reviewed journal
# 2    Conference presentation (oral)
# 3  Conference presentation (poster)
# 4                       Web article
#
#   Publisher/Conference Name URL
# 0
# 1
# 2
# 3
# 4

# %%
this_report.project_status

# %%
this_report.patents_table

# %%
test_file = files[files['year'] == 2024].iloc[1]['file_path']
test_file
# Out:
# WindowsPath('C:/Users/shoffma5/Box/HESTO/HTIDeS/24-HTIDS/24-HTIDS24-0006 Shawn Liang/Reports/HESTO/HESTO-202604_Report_HTIDS24-0006_Liang.pptx')

# %%
this_report = Report(test_file)
# Out:
# HESTO-202604_Report_HTIDS24-0006_Liang.pptx: unrecognised publication type 'Peer-reviewed journal'. Expected one of: ['Peer-reviewed publication', 'Non-Peer-reviewed publication', 'Conference presentation (oral)', 'Conference presentation (poster)', 'Web article']
# HESTO-202604_Report_HTIDS24-0006_Liang.pptx: unrecognised publication type 'Non-peer-reviewed journal'. Expected one of: ['Peer-reviewed publication', 'Non-Peer-reviewed publication', 'Conference presentation (oral)', 'Conference presentation (poster)', 'Web article']

# %%
this_report.accomodation_table
# Out:
#                             category sub_category  \
# 0                       payload size       length
# 1                       payload size        width
# 2                       payload size       height
# 3                     payload volume
# 4                 power requirements
# 5                               mass
# 6              pointing requirements
# 7                          data rate
# 8               power interface port
# 9   communication interface protocol
# 10           data communication port
# 11        requires thermal isolation
# 12      special power considerations
#
#                                                 value
# 0                                                15.0
# 1                                                10.0
# 2                                                10.0
# 3   1.5u (expandable to 2u for additional look dir...
# 4                           3w (average)\n4.5w (peak)
# 5                                               1.4kg
# 6                     not driving \nfov 6 degree fwhm
# 7                            depends on configuration
# 8                                    mdm-9, 28vdc, 1a
# 9                                         uart – lvds
# 10                                             mdm-15
# 11               false (would like to be biased cold)
# 12                                               none

# %%
this_report.summary
# Out:
# {'date': '4/30/2026',
#  'proposal title': 'Shuttered Plasma Instrument for Detecting Environmental Response',
#  'technology name (acronym)': 'SPIDER',
#  'principal investigator': 'Shawn Liang',
#  'pi email': 'Shawn.Liang@jhuapl.edu',
#  'affiliation': 'Johns Hopkins University Applied Physics Laboratory',
#  'proposal id': '24-HTIDS24-0006',
#  'research regime': 'Magnetosphere, Solar Science, Heliosphere, Space Weather',
#  'hesto taxonomy': 'TX08.3.1 Field and Particle Detectors',
#  'instrument type(s)': 'Ionic Particle Sensor/Plasma Detector',
#  'technology keyword': 'Low energy ions',
#  'project summary (two to three sentences)': 'Development of a low SWAP-C instrument that can determine how magnetospheric and solar energy inputs cause the outflow of ionospheric plasma into the magnetosphere, specifically focusing on understanding the composition of the outflowing ions and how this composition changes under different driving conditions. This involves identifying the mechanisms that accelerate ions to escape velocities and resolving uncertainties about the relative proportions of heavy ions, such as N+, and O+, which impact magnetospheric dynamics',
#  'techport url': 'N/A'}
