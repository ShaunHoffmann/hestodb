# %% [markdown]
# # Hesto Notebook (uv environment)
# This notebook is configured to use the workspace Python environment managed by uv (.venv).

# %%
import sys
from pathlib import Path
from datetime import datetime
print(sys.executable)
# Out:
# c:\Users\shoffma5\Documents\GitHub_orig\hestodb\.venv\Scripts\python.exe

# %%
from hestodb.util import parse_file_path, find_latest_report_pptx
from hestodb.report import Report
from hestodb import _test_report_pptx
print(_test_report_pptx)
# Out:
# c:\Users\shoffma5\Documents\GitHub_orig\hestodb\hestodb\data\test\HESTO-202612_Report_24-HTIDS24_Smith-rev3.pptx

# %% [markdown]
# Checking the test file

# %%
test_report = Report(_test_report_pptx)
print(test_report)
# Out:
# Report HESTO-202612_Report_24-HTIDS24_Smith-rev3.pptx (33 slides)
# Project ID: 24-HTIDS24-0009, PI: Jane Smith
#
# Category    Prior    Current
# ----------  -------  -------
# overall     Y        Y
# cost        Y        Y
# schedule    G        G
# technical   G        G
# staffing    G        G
# facilities  G        G
#
# Accommodation:
# Category                          Sub-category  Value
# --------------------------------  ----------  --------------
# payload size                      length      10.0
#                                   width       10.0
#                                   height      10.0
# payload volume                                1.0
# power requirements                average     5.0
#                                   peak        10.0
# mass                                          5.4
# pointing requirements             arcsecs     60.0
#                                   arcminutes  1.0
# data rate                         average     15.0
#                                   peak        100.0
# power interface port                          db-9, 28 v, 1a
# communication interface protocol              uart
# data communication port                       db-9
# requires thermal isolation                    false
# special power considerations                  none
#
# Publications:
#       Type choose one of below                                                   Title Publication/Presentation Date Publisher/Conference Name                                           URL
# Conference presentation (oral) Development of the Next-Generation Solar X-ray detector                   23-Jan-2026              IEEE NSS/MIC https://ieeexplore.ieee.org/document/10657175

# %%
test_report.accomodation_table
# Out:
#                             category sub_category           value
# 0                       payload size       length            10.0
# 1                       payload size        width            10.0
# 2                       payload size       height            10.0
# 3                     payload volume                          1.0
# 4                 power requirements      average             5.0
# 5                 power requirements         peak            10.0
# 6                               mass                          5.4
# 7              pointing requirements      arcsecs            60.0
# 8              pointing requirements   arcminutes             1.0
# 9                          data rate      average            15.0
# 10                         data rate         peak           100.0
# 11              power interface port               db-9, 28 v, 1a
# 12  communication interface protocol                         uart
# 13           data communication port                         db-9
# 14        requires thermal isolation                        false
# 15      special power considerations                         none

# %%
test_report.publication_table
# Out:
#          Type choose one of below  \
# 0  Conference presentation (oral)
#
#                                                Title  \
# 0  Development of the Next-Generation Solar X-ray...
#
#   Publication/Presentation Date Publisher/Conference Name  \
# 0                   23-Jan-2026              IEEE NSS/MIC
#
#                                              URL
# 0  https://ieeexplore.ieee.org/document/10657175

# %%
test_report.patents_table
# Out:
#   Type (Issued, Filing)                                               Name  \
# 0                Issued  Art of transmitting electrical energy through ...
#
#   Patent or License Number        Date  \
# 0                US787412A  1900-05-16
#
#       Resource Link (e.g., Google Patents Link)
# 0  https://patents.google.com/patent/US787412A/

# %%
test_report.student_metrics_table
# Out:
#   Student Name (first last)    Major Affiliation (School, University, etc.)  \
# 0                  John Doe  Physics                  University of Alabama
#
#   Level (High School, Undergrad, Grad, PhD)
# 0                                 Undergrad

# %%
files = find_latest_report_pptx(Path("C:\\Users\\shoffma5\\Box\\HESTO\\HTIDeS"))
print(f"Found {len(files)} report files:")
files.to_csv("report_files.csv", index=False)
files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 files = find_latest_report_pptx(Path("C:\\Users\\shoffma5\\Box\\HESTO\\HTIDeS"))
#       2 print(f"Found {len(files)} report files:")
#       3 files.to_csv("report_files.csv", index=False)
#       4 files
#
# File c:\Users\shoffma5\Documents\GitHub_orig\hestodb\hestodb\util.py:40, in find_latest_report_pptx(root_dir)
#      38 rows = []
#      39 for p in sorted(folders.values(), key=lambda this_p: this_p.name.lower()):
# ---> 40     metadata = parse_file_path(p)
#      41     modified_ts = p.stat().st_mtime
#      42     rows.append(
#      43         {
#      44             "filename": p.name,
#    (...)     52         }
#      53     )
#
# File c:\Users\shoffma5\Documents\GitHub_orig\hestodb\hestodb\util.py:87, in parse_file_path(file_path)
#      82 if len(parts) < 4:
#      83     raise ValueError(f"Unexpected file path structure: {file_path}")
#      84 return {
#      85     "year": int(parts[-5][0:2]) + 2000,
#      86     "project_id": project_id,
# ---> 87     "report_date": report_date,
#      88     "principal_investigator": project_pi,
#      89     "filename": parts[-1],
#      90 }
#
# NameError: name 'report_date' is not defined

# %%
files[files['year'] == 2024]
# Out:
#                                                                                             file_path  \
# filename
# HESTO-202605_TriannualReport_23-HTIDS24-0022_PI...  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3....  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202604_Report_24-HTIDS24-0025_Miller-rev3...  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202604_Report_HTIDS24-0006_Liang.pptx         C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202601_TriannualReport_24-HTIDS24-0003_Eg...  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202605_Report_24-HTIDS24-0039_Kataria-rev...  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202605_Report_Proposal0005_deNolfo_v1.pptx    C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
#
#                                                          project_id  year  \
# filename
# HESTO-202605_TriannualReport_23-HTIDS24-0022_PI...  24-HTIDS24-0022  2024
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3....  24-HTIDS24-0036  2024
# HESTO-202604_Report_24-HTIDS24-0025_Miller-rev3...  24-HTIDS24-0025  2024
# HESTO-202604_Report_HTIDS24-0006_Liang.pptx         24-HTIDS24-0006  2024
# HESTO-202601_TriannualReport_24-HTIDS24-0003_Eg...  24-HTIDS24-0003  2024
# HESTO-202605_Report_24-HTIDS24-0039_Kataria-rev...  24-HTIDS24-0039  2024
# HESTO-202605_Report_Proposal0005_deNolfo_v1.pptx    24-HTIDS24-0005  2024
#
#                                                    principal_investigator  \
# filename
# HESTO-202605_TriannualReport_23-HTIDS24-0022_PI...       Lindsay Glesener
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3....          Maria Usanova
# HESTO-202604_Report_24-HTIDS24-0025_Miller-rev3...         Gregory Miller
# HESTO-202604_Report_HTIDS24-0006_Liang.pptx                   Shawn Liang
# HESTO-202601_TriannualReport_24-HTIDS24-0003_Eg...             Jan Egedal
# HESTO-202605_Report_24-HTIDS24-0039_Kataria-rev...      Dhirendra Kataria
# HESTO-202605_Report_Proposal0005_deNolfo_v1.pptx         Georgia de Nolfo
#
#                                                               modified  \
# filename
# HESTO-202605_TriannualReport_23-HTIDS24-0022_PI... 2026-06-10 10:51:52
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.... 2026-04-24 16:39:00
# HESTO-202604_Report_24-HTIDS24-0025_Miller-rev3... 2026-04-26 16:14:23
# HESTO-202604_Report_HTIDS24-0006_Liang.pptx        2026-04-29 11:58:54
# HESTO-202601_TriannualReport_24-HTIDS24-0003_Eg... 2026-04-30 17:03:16
# HESTO-202605_Report_24-HTIDS24-0039_Kataria-rev... 2026-06-09 15:58:16
# HESTO-202605_Report_Proposal0005_deNolfo_v1.pptx   2026-04-26 13:47:32
#
#                                                                                                folder
# filename
# HESTO-202605_TriannualReport_23-HTIDS24-0022_PI...  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3....  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202604_Report_24-HTIDS24-0025_Miller-rev3...  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202604_Report_HTIDS24-0006_Liang.pptx         C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202601_TriannualReport_24-HTIDS24-0003_Eg...  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202605_Report_24-HTIDS24-0039_Kataria-rev...  C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...
# HESTO-202605_Report_Proposal0005_deNolfo_v1.pptx    C:\Users\shoffma5\Box\HESTO\HTIDeS\24-HTIDS\24...

# %%
test_file = files[files['year'] == 2024].iloc[0]['file_path']

# %%
this_report = Report(test_file)
# Out:
# HESTO-202605_TriannualReport_23-HTIDS24-0022_PI-Glesener-rev4.pptx: unrecognised publication type 'Peer-reviewed journal'. Expected one of: ['Peer-reviewed publication', 'Non-Peer-reviewed publication', 'Conference presentation (oral)', 'Conference presentation (poster)', 'Web article']
# HESTO-202605_TriannualReport_23-HTIDS24-0022_PI-Glesener-rev4.pptx: unrecognised publication type 'Non-peer-reviewed journal'. Expected one of: ['Peer-reviewed publication', 'Non-Peer-reviewed publication', 'Conference presentation (oral)', 'Conference presentation (poster)', 'Web article']

# %%
this_report
# Out:
# Report HESTO-202605_TriannualReport_23-HTIDS24-0022_PI-Glesener-rev4.pptx (35 slides)
# Project ID: 24-HTIDS24-0022, PI: Lindsay Glesener
#
# Accommodation:
# Category                          Sub-category  Value
# --------------------------------  ----------  -------------------------------
# payload size                      length      10.0
#                                   width       10.0
#                                   height      20.0
# payload volume                                2u
# power requirements                            approx. 10 w average
# mass                                          tbd
# pointing requirements             arcsecs     ~1 deg abs. knowledge
#                                   arcminutes  sun-pointed.
# data rate                                     peak 128 mbps
# power interface port                          d-sub 9-pin connector (tbr).
# communication interface protocol              uart (rs-422) or ethernet, tbd.
# data communication port                       db-9 (tbr).
# requires thermal isolation                    false
# special power considerations                  tbd
#
# Publications:
#         Type choose one of below Title Publication/Presentation Date Publisher/Conference Name URL
#            Peer-reviewed journal
#        Non-peer-reviewed journal
#   Conference presentation (oral)
# Conference presentation (poster)
#                      Web article

# %%
this_report.accomodation_table
# Out:
#                             category sub_category  \
# 0                       payload size       length
# 1                       payload size        width
# 2                       payload size       height
# 3                     payload volume
# 4                 power requirements
# 5                               mass
# 6              pointing requirements      arcsecs
# 7              pointing requirements   arcminutes
# 8                          data rate
# 9               power interface port
# 10  communication interface protocol
# 11           data communication port
# 12        requires thermal isolation
# 13      special power considerations
#
#                               value
# 0                              10.0
# 1                              10.0
# 2                              20.0
# 3                                2u
# 4              approx. 10 w average
# 5                               tbd
# 6             ~1 deg abs. knowledge
# 7                      sun-pointed.
# 8                     peak 128 mbps
# 9      d-sub 9-pin connector (tbr).
# 10  uart (rs-422) or ethernet, tbd.
# 11                      db-9 (tbr).
# 12                            false
# 13                              tbd

# %%
this_report.publication_table
# Out:
#            Type choose one of below Title Publication/Presentation Date  \
# 0             Peer-reviewed journal
# 1         Non-peer-reviewed journal
# 2    Conference presentation (oral)
# 3  Conference presentation (poster)
# 4                       Web article
#
#   Publisher/Conference Name URL
# 0
# 1
# 2
# 3
# 4

# %%
this_report.project_status

# %%
this_report.patents_table

# %%
test_file = files[files['year'] == 2024].iloc[1]['file_path']
test_file
# Out:
# WindowsPath('C:/Users/shoffma5/Box/HESTO/HTIDeS/24-HTIDS/24-HTIDS24-0036 Maria Usanova/Reports/HESTO/HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.pptx')

# %%
this_report = Report(test_file)
# Out:
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.pptx: status category 'cost' has invalid prior value 'n/a'. Expected one of: ['g', 'y', 'r', 'green', 'yellow', 'red']
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.pptx: status category 'schedule' has invalid prior value 'n/a'. Expected one of: ['g', 'y', 'r', 'green', 'yellow', 'red']
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.pptx: status category 'technical' has invalid prior value 'n/a'. Expected one of: ['g', 'y', 'r', 'green', 'yellow', 'red']
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.pptx: status category 'staffing' has invalid prior value 'n/a'. Expected one of: ['g', 'y', 'r', 'green', 'yellow', 'red']
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.pptx: status category 'facilities' has invalid prior value 'n/a'. Expected one of: ['g', 'y', 'r', 'green', 'yellow', 'red']
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.pptx: status category 'overall' has invalid prior value 'n/a'. Expected one of: ['g', 'y', 'r', 'green', 'yellow', 'red']
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.pptx: unrecognised publication type 'Peer-reviewed journal'. Expected one of: ['Peer-reviewed publication', 'Non-Peer-reviewed publication', 'Conference presentation (oral)', 'Conference presentation (poster)', 'Web article']
# HESTO-202604_Report_24-HTIDS-0036_Usanova-rev3.pptx: unrecognised publication type 'Non-peer-reviewed journal'. Expected one of: ['Peer-reviewed publication', 'Non-Peer-reviewed publication', 'Conference presentation (oral)', 'Conference presentation (poster)', 'Web article']

# %%
this_report.accomodation_table
# Out:
#                             category sub_category value
# 0                       payload size       length   6.0
# 1                       payload size        width   6.0
# 2                       payload size       height   6.0
# 3                     payload volume                1.0
# 4                 power requirements                1.0
# 5                               mass                tbd
# 6              pointing requirements                tbd
# 7                          data rate                tbd
# 8               power interface port                tbd
# 9   communication interface protocol                tbd
# 10           data communication port                tbd
# 11        requires thermal isolation               true
# 12      special power considerations               none

# %%
this_report.summary
# Out:
# {'date': '04/04/2026',
#  'proposal title': 'A Magnetometer Based on Magneto-Optical Effects for Space Applications',
#  'technology name (acronym)': 'MiniMag',
#  'principal investigator': 'Maria Usanova',
#  'pi email': 'Maria.Usanova@lasp.colorado.edu',
#  'affiliation': 'University of Colorado Boulder',
#  'proposal id': '24-HTIDS24-0036',
#  'research regime': 'Magnetosphere',
#  'hesto taxonomy': 'TX08.3.1 Field and Particle Detectors',
#  'instrument type(s)': 'Magnetometer',
#  'technology keyword': 'N/A',
#  'project summary (two to three sentences)': 'Advance MiniMag from TRL 2-3 to TRL 6 by optimizing a sensor and developing a compact, low-SWaP magnetometer. The effort targets improved sensitivity and measurements from DC to 40 kHz, culminating in demonstration of a 1-axis instrument in a relevant environment.',
#  'techport url': 'TBD'}

# %%
files = find_latest_report_pptx(Path("C:\\Users\\shoffma5\\Box\\HESTO\\HFOS"))
print(f"Found {len(files)} report files:")
files.to_csv("report_files.csv", index=False)
files
# Out:
# Found 13 report files:
#                                                                                             file_path  \
# filename
# HESTO-202605_TriannualReport_80NSSC25K7958_Moor...  C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...
# HESTO-202604_Report_P24-HFOS24-0013_Holsclaw.pptx   C:\Users\shoffma5\Box\HESTO\HFOS\24-HFOS\24-HF...
# HESTO-202604_Report_23-HFOS23-0003_Zhao.pptx        C:\Users\shoffma5\Box\HESTO\HFOS\23-HFOS\23-HF...
# HESTO-202504_HFOS Quarterly Report_22-HFOS22-00...  C:\Users\shoffma5\Box\HESTO\HFOS\22-HFOS\22-HF...
# HESTO-202501_HFOS Quarterly Report_22-HFOS22-00...  C:\Users\shoffma5\Box\HESTO\HFOS\22-HFOS\22-HF...
